# %% [markdown]
# # Lab 7: PHÂN TÍCH DỮ LIỆU DẠNG VĂN BẢN VỚI NLTK

# %% [markdown]
# ### 1. Giới thiệu về thư viện NLTK:

# %%
# %pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\T.Hung\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
gb = nltk.corpus.gutenberg  
print("Gutenberg files : ", gb.fileids())
# Out:
# Gutenberg files :  ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']

# %%
macbeth = nltk.corpus.gutenberg.words('shakespeare-macbeth.txt')

# %%
len(macbeth)
# Out:
# 23140

# %%
macbeth[:10]
# Out:
# ['[',
#  'The',
#  'Tragedie',
#  'of',
#  'Macbeth',
#  'by',
#  'William',
#  'Shakespeare',
#  '1603',
#  ']']

# %%
macbeth_sents = nltk.corpus.gutenberg.sents('shakespeare-macbeth.txt')
macbeth_sents[:5]
# Out:
# [['[',
#   'The',
#   'Tragedie',
#   'of',
#   'Macbeth',
#   'by',
#   'William',
#   'Shakespeare',
#   '1603',
#   ']'],
#  ['Actus', 'Primus', '.'],
#  ['Scoena', 'Prima', '.'],
#  ['Thunder', 'and', 'Lightning', '.'],
#  ['Enter', 'three', 'Witches', '.']]

# %% [markdown]
# ### 2. Tìm 1 từ với NLTK:

# %%
text = nltk.Text(macbeth) 
text.concordance('Stage')
# Out:
# Displaying 3 of 3 matches:
# nts with Dishes and Seruice ouer the Stage . Then enter Macbeth Macb . If it we
# with mans Act , Threatens his bloody Stage : byth ' Clock ' tis Day , And yet d
#  struts and frets his houre vpon the Stage , And then is heard no more . It is

# %%
text.common_contexts(['Stage'])
# Out:
# the_. bloody_: the_,

# %%
text.similar('Stage')
# Out:
# day time face warre ayre king bleeding man reuolt serieant like
# knowledge broyle shew head spring heeles hare thane skie

# %% [markdown]
# ### 3. Phân tích tần số của các từ

# %%
fd = nltk.FreqDist(macbeth)  
fd.most_common(10)
# Out:
# [(',', 1962),
#  ('.', 1235),
#  ("'", 637),
#  ('the', 531),
#  (':', 477),
#  ('and', 376),
#  ('I', 333),
#  ('of', 315),
#  ('to', 311),
#  ('?', 241)]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\T.Hung\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
sw = set(nltk.corpus.stopwords.words('english'))  
print(len(sw)) 
list(sw)[:10]
# Out:
# 198
# ['on', 'these', 's', 'how', "they'd", 'being', 'in', 'isn', 'our', 'y']

# %%
macbeth_filtered = [w for w in macbeth if w.lower() not in sw] 
len(macbeth_filtered)
# Out:
# 14946

# %%
fd = nltk.FreqDist(macbeth_filtered)  
fd.most_common(10)
# Out:
# [(',', 1962),
#  ('.', 1235),
#  ("'", 637),
#  (':', 477),
#  ('?', 241),
#  ('Macb', 137),
#  ('haue', 117),
#  ('-', 100),
#  ('Enter', 80),
#  ('thou', 63)]

# %%
import string 
punctuation = set(string.punctuation)  
macbeth_filtered2 = [w.lower() for w in macbeth if w.lower() not in sw and w.lower() not in punctuation]  
fd = nltk.FreqDist(macbeth_filtered2)  
fd.most_common(10)
# Out:
# [('macb', 137),
#  ('haue', 122),
#  ('thou', 90),
#  ('enter', 81),
#  ('shall', 68),
#  ('macbeth', 62),
#  ('vpon', 62),
#  ('thee', 61),
#  ('macd', 58),
#  ('vs', 57)]

# %% [markdown]
# ### 4. Lựa chọn các từ trong văn bản

# %%
long_words = [w for w in macbeth if len(w)> 12] 
sorted(long_words)
# Out:
# ['Assassination',
#  'Chamberlaines',
#  'Distinguishes',
#  'Gallowgrosses',
#  'Metaphysicall',
#  'Northumberland',
#  'Voluptuousnesse',
#  'commendations',
#  'multitudinous',
#  'supernaturall',
#  'vnaccompanied']

# %%
ious_words = [w for w in macbeth if 'ious' in w] 
ious_words = set(ious_words) 
sorted(ious_words)
# Out:
# ['Auaricious',
#  'Gracious',
#  'Industrious',
#  'Iudicious',
#  'Luxurious',
#  'Malicious',
#  'Obliuious',
#  'Pious',
#  'Rebellious',
#  'compunctious',
#  'furious',
#  'gracious',
#  'pernicious',
#  'pernitious',
#  'pious',
#  'precious',
#  'rebellious',
#  'sacrilegious',
#  'serious',
#  'spacious',
#  'tedious']

# %% [markdown]
# ### 5. Bigrams và collocations

# %%
bgrms = nltk.FreqDist(nltk.bigrams(macbeth_filtered2)) 
bgrms.most_common(15)
# Out:
# [(('enter', 'macbeth'), 16),
#  (('exeunt', 'scena'), 15),
#  (('thane', 'cawdor'), 13),
#  (('knock', 'knock'), 10),
#  (('st', 'thou'), 9),
#  (('thou', 'art'), 9),
#  (('lord', 'macb'), 9),
#  (('haue', 'done'), 8),
#  (('macb', 'haue'), 8),
#  (('good', 'lord'), 8),
#  (('let', 'vs'), 7),
#  (('enter', 'lady'), 7),
#  (('wee', 'l'), 7),
#  (('would', 'st'), 6),
#  (('macbeth', 'macb'), 6)]

# %%
tgrms = nltk.FreqDist(nltk.trigrams (macbeth_filtered2)) 
tgrms.most_common(10)
# Out:
# [(('knock', 'knock', 'knock'), 6),
#  (('enter', 'macbeth', 'macb'), 5),
#  (('enter', 'three', 'witches'), 4),
#  (('exeunt', 'scena', 'secunda'), 4),
#  (('good', 'lord', 'macb'), 4),
#  (('three', 'witches', '1'), 3),
#  (('exeunt', 'scena', 'tertia'), 3),
#  (('thunder', 'enter', 'three'), 3),
#  (('exeunt', 'scena', 'quarta'), 3),
#  (('scena', 'prima', 'enter'), 3)]

# %% [markdown]
# ### 6. Sử dụng văn bản trên mạng

# %%
from urllib import request 
url = "http://www.gutenberg.org/files/2554/2554-0.txt" 
response = request.urlopen(url) 
raw = response.read().decode('utf8') 
raw[:75]
# Out:
# '*** START OF THE PROJECT GUTENBERG EBOOK 2554 ***\n\n\n\n\nCRIME AND PUNISHMENT\n'

# %%
from urllib import request 
url = "http://www.gutenberg.org/files/2554/2554-0.txt" 
response = request.urlopen(url) 
raw = response.read().decode('utf-8-sig')
raw[:75]
# Out:
# '*** START OF THE PROJECT GUTENBERG EBOOK 2554 ***\n\n\n\n\nCRIME AND PUNISHMENT\n'

# %%
tokens = nltk.word_tokenize (raw) 
webtext = nltk.Text (tokens) 
webtext[:12]
# Out:
# ['*',
#  '*',
#  '*',
#  'START',
#  'OF',
#  'THE',
#  'PROJECT',
#  'GUTENBERG',
#  'EBOOK',
#  '2554',
#  '*',
#  '*']

# %% [markdown]
# ### 7. Rút trích văn bản từ trang html

# %%
url = "http://news.bbc.co.uk/2/hi/health/2284783.stm" 
html = request.urlopen(url).read().decode('utf8') 
html[:120]
# Out:
# '<!doctype html public "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/REC-html40/loose.dtd">\r\n<html>\r\n<hea'

# %%
from bs4 import BeautifulSoup 
raw = BeautifulSoup(html, "lxml").get_text() 
tokens = nltk.word_tokenize(raw) 
text = nltk.Text(tokens)

# %% [markdown]
# ### 8. Phân tích cảm xúc người dùng

# %%
nltk.download('movie_reviews')
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\T.Hung\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# True

# %%
import random 
reviews = nltk.corpus.movie_reviews 
documents = [(list(reviews.words(fileid)), category)
for category in reviews.categories() 
for fileid in reviews.fileids(category)] 
random.shuffle(documents)

# %%
first_review = ' '.join(documents[0][0]) 
print(first_review)
# Out:
# synopsis : leonard shelby ( pearce ) is a former insurance investigator on the trail of the man who killed his wife . leonard has only a few clues to the murderer ' s identity ; to make matters worse , he suffers from a condition which inhibits the creation of short - term memories , meaning that leonard is always forgetting what happened just minutes earlier . because of this , leonard is forced to rely on notes he leaves for himself . " memento " traces the investigation back in time from its apparent culmination . review : " memento " is the sort of movie i wish i ' d written ; i can think of no higher praise than that . i am envious that nolan has concocted such a brilliant , involved , original movie as this . an instant film noir classic , " memento " is virtually flawless . the script is unlike any i have ever seen -- a notable achievement in these days of recycled hollywood homogeneity . although the idea of starting at the " conclusion " of the plotline and then moving backw
# ...

# %%
documents[0][1]
# Out:
# 'pos'

# %%
all_words = nltk.FreqDist(w.lower() for w in reviews.words()) 
word_features = list(all_words)

# %%
def document_features(document, word_features):  
    document_words = set(document) 
    features = {} 
    for word in word_features: 
        features['{}'.format(word)] = (word in document_words) 
    return features

# %%
featuresets = [(document_features(d,word_features), c) for (d,c) in documents] 
len(featuresets)
# Out:
# 2000

# %%
train_set, test_set = featuresets[1500:], featuresets[:500] 
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
train_set, est_set = featuresets[1500:], featuresets[:500] 
classifier = nltk.NaiveBayesClassifier.train(train_set) 
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.764

# %%
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#                     warm = True              pos : neg    =     10.4 : 1.0
#                    awful = True              neg : pos    =     10.1 : 1.0
#                    clich = True              neg : pos    =     10.1 : 1.0
#                      sat = True              neg : pos    =     10.1 : 1.0
#                 strength = True              pos : neg    =      8.6 : 1.0
#                       it = False             neg : pos    =      8.6 : 1.0
#                     skip = True              neg : pos    =      7.8 : 1.0
#                   hearts = True              pos : neg    =      7.5 : 1.0
#                    shine = True              pos : neg    =      7.5 : 1.0
#                   period = True              pos : neg    =      7.3 : 1.0

# %% [markdown]
# ### 9. Bài tập áp dụng

# %%
import nltk
import random
from nltk.corpus import stopwords, wordnet as wn, names
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('tagsets')
nltk.download('punkt')
nltk.download('names')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\T.Hung\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\T.Hung\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\T.Hung\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package tagsets to
# [nltk_data]     C:\Users\T.Hung\AppData\Roaming\nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\T.Hung\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\T.Hung\AppData\Roaming\nltk_data...
# [nltk_data]   Package names is already up-to-date!
# ...

# %% [markdown]
# 1. Viết chương trình Python với thư viện NLTK để liệt kê các tên của copus.

# %%
corpus_names = [corpus for corpus in dir(nltk.corpus) if not corpus.startswith('_')]
print(f"Tổng số corpus tìm thấy: {len(corpus_names)}")
print(corpus_names[:20])
# Out:
# Tổng số corpus tìm thấy: 157
# ['AlignedCorpusReader', 'AlpinoCorpusReader', 'BCP47CorpusReader', 'BNCCorpusReader', 'BracketParseCorpusReader', 'CHILDESCorpusReader', 'CMUDictCorpusReader', 'CategorizedBracketParseCorpusReader', 'CategorizedCorpusReader', 'CategorizedPlaintextCorpusReader', 'CategorizedSentencesCorpusReader', 'CategorizedTaggedCorpusReader', 'ChasenCorpusReader', 'ChunkedCorpusReader', 'ComparativeSentencesCorpusReader', 'ConllChunkCorpusReader', 'ConllCorpusReader', 'CorpusReader', 'CrubadanCorpusReader', 'DependencyCorpusReader']

# %% [markdown]
# 2. Viết chương trình Python với thư viện NLTK để liệt kê danh sách các stopword bằng các
# ngôn ngữ khác nhau.

# %%
languages = stopwords.fileids()
print(f"{len(languages)}")
print(languages)
# Out:
# 33
# ['albanian', 'arabic', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'tamil', 'turkish', 'uzbek']

# %% [markdown]
# 3. Viết chương trình Python với thư viện NLTK để kiểm tra danh sách các stopword bằng các
# ngôn ngữ khác nhau.

# %%
print("25 Stopwords tiếng Anh:", stopwords.words('english')[:25])
print("25 Stopwords tiếng Pháp:", stopwords.words('french')[:25])
print("25 Stopwords tiếng Tàu:", stopwords.words('chinese')[:25])
# Out:
# 25 Stopwords tiếng Anh: ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both']
# 25 Stopwords tiếng Pháp: ['au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', 'elle', 'en', 'et', 'eux', 'il', 'ils', 'je', 'la', 'le', 'les', 'leur', 'lui', 'ma', 'mais', 'me', 'même']
# 25 Stopwords tiếng Tàu: ['一', '一下', '一些', '一切', '一则', '一天', '一定', '一方面', '一旦', '一时', '一来', '一样', '一次', '一片', '一直', '一致', '一般', '一起', '一边', '一面', '万一', '上下', '上升', '上去', '上来']

# %% [markdown]
# 4. Viết chương trình Python với thư viện NLTK để loại bỏ các stopword từ một văn bản đã cho.

# %%
vb = "This is an example sentence to demonstrate the removal of stopwords using NLTK in Python."
stop_words_en = set(stopwords.words('english'))
tu_vung = word_tokenize(vb)
# Lọc bỏ stopwords
loc_vb = [tu for tu in tu_vung if tu.lower() not in stop_words_en]

print("Văn bản gốc:", vb)
print("Sau khi loại bỏ stopwords:", " ".join(loc_vb))
# Out:
# Văn bản gốc: This is an example sentence to demonstrate the removal of stopwords using NLTK in Python.
# Sau khi loại bỏ stopwords: example sentence demonstrate removal stopwords using NLTK Python .

# %% [markdown]
# 5. Viết chương trình Python với thư viện NLTK bỏ qua các stopword từ danh sách các
# stopword.

# %%
stop_words_tuy_chinh = set(stopwords.words('english'))

tu_can_giu_lai = ['is', 'to', 'the'] 
for tu in tu_can_giu_lai:
    if tu in stop_words_tuy_chinh:
        stop_words_tuy_chinh.remove(tu)

# Kiểm tra lại
van_ban_da_loc_2 = [tu for tu in tu_vung if tu.lower() not in stop_words_tuy_chinh]

print("Danh sách từ bị giữ lại:", tu_can_giu_lai)
print("Sau khi giữ lại một số stopword:", " ".join(van_ban_da_loc_2))
# Out:
# Danh sách từ bị giữ lại: ['is', 'to', 'the']
# Sau khi giữ lại một số stopword: is example sentence to demonstrate the removal stopwords using NLTK Python .

# %% [markdown]
# 6. Viết một chương trình Python với thư viện NLTK để tìm định nghĩa và ví dụ của một từ đã
# cho bằng WordNet từ Wikipedia,

# %%
tu_khoa = "computer"
synsets = wn.synsets(tu_khoa)

if synsets:
    synset_dau_tien = synsets[0]
    print(f"Từ khóa: {tu_khoa}")
    print(f"Định nghĩa: {synset_dau_tien.definition()}")
    print(f"Ví dụ: {synset_dau_tien.examples()}")
else:
    print("Không tìm thấy từ trong WordNet.")
# Out:
# Từ khóa: computer
# Định nghĩa: a machine for performing calculations automatically
# Ví dụ: []

# %% [markdown]
# 7. Viết chương trình Python với thư viện NLTK để tìm tập hợp các từ đồng nghĩa và trái nghĩa
# của một từ nào đó.

# %%
tu_khoa_7 = "good"
dong_nghia = set()
trai_nghia = set()

for syn in wn.synsets(tu_khoa_7):
    for lemma in syn.lemmas():
        dong_nghia.add(lemma.name())
        # Nếu có từ trái nghĩa
        if lemma.antonyms():
            trai_nghia.add(lemma.antonyms()[0].name())

print(f"Từ khóa: {tu_khoa_7}")
print("Từ đồng nghĩa:", list(dong_nghia)[:10]) # In tối đa 10 từ
print("Từ trái nghĩa:", list(trai_nghia)[:10])
# Out:
# Từ khóa: good
# Từ đồng nghĩa: ['beneficial', 'honest', 'good', 'skillful', 'safe', 'near', 'full', 'estimable', 'respectable', 'dear']
# Từ trái nghĩa: ['bad', 'ill', 'badness', 'evil', 'evilness']

# %% [markdown]
# 8. Viết chương trình Python với thư viện NLTK để có cái nhìn tổng quan về bộ tag, chi tiết của
# một tag cụ thể trong bộ tag và chi tiết về một số bộ tag liên quan, sử dụng biểu thức chính
# quy.

# %%
import nltk

print("1. Chi tiết một tag cụ thể (VD: NN):")
nltk.help.upenn_tagset('NN')

print("\n2. Chi tiết các tag liên quan bằng regex:")
nltk.help.upenn_tagset('NN.*')
# Out:
# 1. Chi tiết một tag cụ thể (VD: NN):
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
#
# 2. Chi tiết các tag liên quan bằng regex:
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
# ...

# %% [markdown]
# 9. Viết chương trình Python với thư viện NLTK để so sánh sự giống nhau của hai danh từ đã
# cho.

# %%
danh_tu_1 = wn.synset('cat.n.01')
danh_tu_2 = wn.synset('dog.n.01')
danh_tu_3 = wn.synset('car.n.01')
do_tuong_dong_1_2 = danh_tu_1.wup_similarity(danh_tu_2) # Wu-Palmer Similarity
do_tuong_dong_1_3 = danh_tu_1.wup_similarity(danh_tu_3)

print(f"Sự giống nhau giữa Mèo (cat) và Chó (dog): {do_tuong_dong_1_2:.4f}")
print(f"Sự giống nhau giữa Mèo (cat) và Ô tô (car): {do_tuong_dong_1_3:.4f}")
# Out:
# Sự giống nhau giữa Mèo (cat) và Chó (dog): 0.8571
# Sự giống nhau giữa Mèo (cat) và Ô tô (car): 0.3200

# %% [markdown]
# 10. Viết chương trình Python với thư viện NLTK để so sánh sự giống nhau của hai động từ đã
# cho.

# %%
dong_tu_1 = wn.synset('run.v.01')
dong_tu_2 = wn.synset('walk.v.01')
dong_tu_3 = wn.synset('eat.v.01')

tuong_dong_v_1_2 = dong_tu_1.wup_similarity(dong_tu_2)
tuong_dong_v_1_3 = dong_tu_1.wup_similarity(dong_tu_3)

print(f"Sự giống nhau giữa Chạy (run) và Đi bộ (walk): {tuong_dong_v_1_2:.4f}")
print(f"Sự giống nhau giữa Chạy (run) và Ăn (eat): {tuong_dong_v_1_3:.4f}")
# Out:
# Sự giống nhau giữa Chạy (run) và Đi bộ (walk): 0.2857
# Sự giống nhau giữa Chạy (run) và Ăn (eat): 0.2857

# %% [markdown]
# 11. Viết chương trình Python với thư viện NLTK để tìm số lượng tên nam và nữ trong các tên
# kho ngữ liệu. In tên 10 nam và nữ đầu tiên. Lưu ý: Kho văn bản tên chứa tổng cộng khoảng
# 2943 nam (male.txt) và 5001 nữ (Female.txt) tên. Kho được biên soạn bởi Kantrowitz, Ross.

# %%
ten_nam = names.words('male.txt')
ten_nu = names.words('female.txt')

print(f"Tổng số tên nam: {len(ten_nam)}")
print(f"Tổng số tên nữ: {len(ten_nu)}")
print("10 tên nam đầu tiên:", ten_nam[:10])
print("10 tên nữ đầu tiên:", ten_nu[:10])
# Out:
# Tổng số tên nam: 2943
# Tổng số tên nữ: 5001
# 10 tên nam đầu tiên: ['Aamir', 'Aaron', 'Abbey', 'Abbie', 'Abbot', 'Abbott', 'Abby', 'Abdel', 'Abdul', 'Abdulkarim']
# 10 tên nữ đầu tiên: ['Abagael', 'Abagail', 'Abbe', 'Abbey', 'Abbi', 'Abbie', 'Abby', 'Abigael', 'Abigail', 'Abigale']

# %% [markdown]
# 12. Viết chương trình Python với thư viện NLTK để in 15 kết hợp ngẫu nhiên đầu tiên được gắn
# nhãn nam và được gắn nhãn tên nữ từ kho tên.

# %%
danh_sach_nhan = [(ten, 'male') for ten in ten_nam] + [(ten, 'female') for ten in ten_nu]

random.seed(42)
random.shuffle(danh_sach_nhan)
for item in danh_sach_nhan[:15]:
    print(item)
# Out:
# ('Raye', 'female')
# ('Marita', 'female')
# ('Fey', 'female')
# ('Vittoria', 'female')
# ('Dannie', 'female')
# ('Annabela', 'female')
# ('Sayre', 'male')
# ('Brock', 'male')
# ('Angel', 'female')
# ('Bride', 'female')
# ('Ruthanne', 'female')
# ('Davina', 'female')
# ('Kingsley', 'male')
# ('Trixy', 'female')
# ('Shaine', 'female')

# %% [markdown]
# 13. Viết chương trình Python với thư viện NLTK để trích xuất ký tự cuối cùng của tất cả các tên
# được gắn nhãn và tạo mảng mới với chữ cái cuối cùng của mỗi tên và nhãn được liên kết.

# %%
mang_ky_tu_cuoi = [(ten[-1].lower(), gioi_tinh) for ten, gioi_tinh in danh_sach_nhan]
for item in mang_ky_tu_cuoi[:15]:
    print(item)
# Out:
# ('e', 'female')
# ('a', 'female')
# ('y', 'female')
# ('a', 'female')
# ('e', 'female')
# ('a', 'female')
# ('e', 'male')
# ('k', 'male')
# ('l', 'female')
# ('e', 'female')
# ('e', 'female')
# ('a', 'female')
# ('y', 'male')
# ('y', 'female')
# ('e', 'female')
